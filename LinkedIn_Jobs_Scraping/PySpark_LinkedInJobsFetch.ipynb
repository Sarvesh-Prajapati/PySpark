# %% [markdown]
# # **Fetch using PySpark**

# %%
import requests
import os
import pandas as pd
import pyspark
from pyspark.sql import SparkSession
from pyspark.sql.functions import *
from bs4 import BeautifulSoup

# %% [markdown]
# **Hit a Google search for data analyst jobs, open the LinkedIn result in new tab, copy the URL and follow next steps:**

# %%
job_url = "https://www.linkedin.com/jobs/search?keywords=Data%20Analyst&location=&geoId=&trk=public_jobs_jobs-search-bar_search-submit&position=1&pageNum=0"
souped = requests.get(job_url)  # '.get()' returns HTML content in jumbled form
job_html = BeautifulSoup(souped.content, "html.parser")  # formatting the HTML content

# Fetching the job titles (job positions)
job_list = []
job_titles = job_html.find_all('h3', {'class' : 'base-search-card__title'}) # finding all <H3> html tags of specified class
for i in job_titles: job_list.append(i.getText().strip()) # 'getText()' returns text content of <H3> tag; 'strip()' crops leading/lagging spaces

# Fetching name of the company offering each job
job_company = []
company_name = job_html.find_all('h4', {'class' : 'base-search-card__subtitle'})
for i in company_name: job_company.append(i.getText().strip())

# Fetch job location
job_location = []
location = job_html.find_all('span', {'class' : 'job-search-card__location'})
for i in location: job_location.append(i.getText().strip())

# Recency of job posting
job_recency = []
recency1 = job_html.find_all('time', {'class' : 'job-search-card__listdate--new'})
recency2 = job_html.find_all('time', {'class' : 'job-search-card__listdate'})
for i in recency1: job_recency.append(i.getText().strip())
for i in recency2: job_recency.append(i.getText().strip())

# %%
# Create a spark session

spark = SparkSession.builder.appName('LinkedInJobFetch').getOrCreate()

# %%
data = {'Job_Title' : job_list,
        'Company' : job_company,
        'Location' : job_location,
        'Job_Recency' : job_recency }

col_headings = list(data.keys())    # This will be used later to assign col headings

spark_data = list(zip(*data.values()))
spark_df = spark.createDataFrame(spark_data)  # Creating Spark dataframe

# spark_df.show(n = spark_df.count(), truncate=False)

csv_path = '/content/spark_linkedin_jobs'  # Saving file in Colab's local storage in a dedicated folder

if os.path.exists(csv_path):   # If path exists
    spark_df.write.csv(csv_path, mode = "append", header = False)  # Append new data EXCLUDING header row
    print(f"Data APPENDED to {csv_path}")
else:
    spark_df.write.csv(csv_path, mode = "overwrite", header = False)  # At first-time write, INCLUDE header columns
    print(f"Data SAVED to {csv_path}")  # Printed ONLY ON FIRST RUN of this cell; next run onward, 'print' in above 'if' runs
# Out:
# Data SAVED to /content/spark_linkedin_jobs

# %%
from pyspark.sql.types import StructType, StructField, StringType

# Define column headers' schema
col_schema = StructType([
    StructField(col_headings[0], StringType(), True),
    StructField(col_headings[1], StringType(), True),
    StructField(col_headings[2], StringType(), True),
    StructField(col_headings[3], StringType(), True) ])

# Reading the content of 'spark_linkedin_jobs.csv'
r = spark.read.csv('/content/spark_linkedin_jobs', schema = col_schema, multiLine = True)

r.dropDuplicates() # Remove duplicate rows

r.show(n = r.count(), truncate=False)  # 'r.count()' returns the total no. of rows
# Out:
# +-------------------------------------------+--------------------------------------+-------------------------------+------------+
# |Job_Title                                  |Company                               |Location                       |Job_Recency |
# +-------------------------------------------+--------------------------------------+-------------------------------+------------+
# |Data Analyst, Finance & Strategy, MarComms |Netflix                               |Los Angeles, CA                |17 hours ago|
# |Data Analyst                               |KFC                                   |Plano, TX                      |8 hours ago |
# |Analyst, Insights & Analytics              |LoopMe                                |New York, NY                   |19 hours ago|
# |Data Analyst                               |CULT GAIA                             |Los Angeles Metropolitan Area  |1 week ago  |
# |Data Analyst                               |Zest AI                               |Burbank, CA                    |4 days ago  |
# |Data Analyst                               |Cloudflare                            |Austin, TX                     |2 weeks ago |
# |Data Analyst                               |Kforce Inc                            |New York, NY                   |3 days ago  |
# |Data Analyst, Pricing                      |Lyft                                  |Seattle, WA                    |1 week ago  |
# |Data Analyst                               |Upstart                               |United States                  |1 week ago  |
# |Data Analyst                               |Birlasoft                             |Charlotte, NC                  |1 week ago  |
# |Data Analyst                               |Cloudflare                            |Dallas, TX                     |1 week ago  |
# |Analyst, Analytics                         |Toyota North America                  |Plano, TX                      |1 week ago  |
# |Data Analyst                               |Memorial Sloan Kettering Cancer Center|New York, NY                   |2 weeks ago |
# |Sales Data Analyst                         |Morgan Stanley                        |Boston, MA                     |1 week ago  |
# |Data Analyst Intern 2025                   |Voloridge Investment Management, LLC  |Jupiter, FL                    |5 days ago  |
# |Data Analyst                               |Cloudflare                            |Houston, TX                    |2 weeks ago |
# |Data Analyst                               |Radiant Digital                       |Brooklyn, NY                   |2 weeks ago |
# |Data Analyst                               |Synapticure                           |Chicago, IL                    |1 week ago  |
# |Data Analyst I                             |Protingent                            |Charlotte, NC                  |4 weeks ago |
# |Data Analyst                               |Healthcasts Media                     |New York City Metropolitan Area|6 days ago  |
# |Data Analyst - Power BI, SQL, & Python     |Insight Global                        |Charlotte Metro                |6 days ago  |
# |Data Analyst                               |QSC                                   |United States                  |1 week ago  |
# |Junior Data Analyst (contingent)           |ARETUM                                |Washington, DC                 |1 week ago  |
# |Data Analyst                               |Cloudflare                            |San Antonio, TX                |3 days ago  |
# |Senior Data Analyst (NY Hybrid)            |Experian                              |New York, NY                   |1 week ago  |
# |Data Analyst  (251934)                     |Eastridge Workforce Solutions         |New York, NY                   |1 week ago  |
# |Business Data Analyst                      |Mirion                                |Atlanta, GA                    |6 days ago  |
# |Data Analyst                               |Korn Ferry                            |California, United States      |1 week ago  |
# |Data Analyst                               |Advize                                |United States                  |4 days ago  |
# |Data Analyst                               |Korn Ferry                            |Washington DC-Baltimore Area   |2 weeks ago |
# |Data Analyst                               |Counterpart                           |United States                  |4 days ago  |
# |Data Analyst - (SQL / Looker - 100% Remote)|Optomi                                |New Jersey, United States      |1 week ago  |
# |Data Analyst                               |Cloud and Things                      |United States                  |1 week ago  |
# |Data Analyst                               |Medterra                              |United States                  |1 week ago  |
# |Data Analyst                               |Dexian                                |Tampa, FL                      |4 days ago  |
# |Data Analyst                               |Korn Ferry                            |Florida, United States         |1 week ago  |
# |Data Analyst                               |Tata Consultancy Services             |Irving, TX                     |4 days ago  |
# |Data Analyst                               |YunoJuno                              |United States                  |1 week ago  |
# |Data Analyst                               |Bamboo Insurance                      |United States                  |1 week ago  |
# |Data Analyst                               |Elder Research                        |Arlington, VA                  |6 days ago  |
# |Data Analyst                               |Korn Ferry                            |Georgia, United States         |1 week ago  |
# |Data Analyst - Marketing                   |FanDuel                               |New York, NY                   |4 days ago  |
# |Analyst II, Data and Insights              |Herbalife                             |Torrance, CA                   |3 days ago  |
# |Data Analyst                               |Korn Ferry                            |Virginia, United States        |1 week ago  |
# |Junior Data Analyst                        |Sesheng                               |United States                  |4 days ago  |
# |Data Analyst                               |Akkodis                               |United States                  |2 days ago  |
# |Business Data Analyst                      |Volt                                  |Sparks, NV                     |2 weeks ago |
# |Data Analyst                               |Numero Data                           |Herndon, VA                    |2 weeks ago |
# |Data Analyst                               |MGT                                   |Tinley Park, IL                |1 week ago  |
# |Data Analyst                               |PRI Global                            |United States                  |4 days ago  |
# |Senior Data Analyst                        |CyberCoders                           |Normal, IL                     |2 weeks ago |
# |Data Analyst                               |The Cypress Group                     |New York City Metropolitan Area|1 week ago  |
# |Data Analyst                               |IT Labs                               |United States                  |1 week ago  |
# |Data Analyst                               |Planet Interactive                    |San Francisco, CA              |1 week ago  |
# |Data Analyst                               |Korn Ferry                            |Delaware, United States        |4 days ago  |
# |Data Analysts                              |AutoRoboto                            |Mountain View, CA              |1 week ago  |
# |Data Analyst                               |Flexton Inc.                          |Cincinnati Metropolitan Area   |3 days ago  |
# |Data Analyst                               |Korn Ferry                            |Arkansas, United States        |4 days ago  |
# |Data Analyst                               |Korn Ferry                            |Connecticut, United States     |4 days ago  |
# |Data Analyst                               |Korn Ferry                            |Idaho, United States           |4 days ago  |
# +-------------------------------------------+--------------------------------------+-------------------------------+------------+

# %%
r.count()
# Out:
# 60

# %% [markdown]
# **The first run is done (until the above cell). Now let us run the above code again to get next results of jobs and see what changes. We'll run all BUT the spark session creation cell above, again:**

# %%
job_url = "https://www.linkedin.com/jobs/search?keywords=Data%20Analyst&location=&geoId=&trk=public_jobs_jobs-search-bar_search-submit&position=1&pageNum=0"
souped = requests.get(job_url)  # '.get()' returns HTML content in jumbled form
job_html = BeautifulSoup(souped.content, "html.parser")  # formatting the HTML content

#Fetching the job titles (job positions)
job_list = []
job_titles = job_html.find_all('h3', {'class' : 'base-search-card__title'}) # finding all <H3> html tags of specified class
for i in job_titles: job_list.append(i.getText().strip()) # 'getText()' returns text content of <H3> tag; 'strip()' crops leading/lagging spaces

#Fetching name of the company offering each job
job_company = []
company_name = job_html.find_all('h4', {'class' : 'base-search-card__subtitle'})
for i in company_name: job_company.append(i.getText().strip())

#Fetch job location
job_location = []
location = job_html.find_all('span', {'class' : 'job-search-card__location'})
for i in location: job_location.append(i.getText().strip())

#Recency of job posting
job_recency = []
recency1 = job_html.find_all('time', {'class' : 'job-search-card__listdate--new'})
recency2 = job_html.find_all('time', {'class' : 'job-search-card__listdate'})
for i in recency1: job_recency.append(i.getText().strip())
for i in recency2: job_recency.append(i.getText().strip())

# %% [markdown]
# **Pay attention to the next cell's run; note which** ```print``` **runs here (tally with that in first run above).**

# %%
csv_path = '/content/spark_linkedin_jobs'  # Saving file in Colab's local storage in a dedicated folder

data.clear() # Clearing any previous content of dictionary 'data'

data = {'Job_Title' : job_list,
        'Company' : job_company,
        'Location' : job_location,
        'Job_Recency' : job_recency }

spark_data = list(zip(*data.values()))
spark_df = spark.createDataFrame(spark_data)  # Creating Spark dataframe

# spark_df.show(n = spark_df.count(), truncate=False)

if os.path.exists(csv_path):   # If path exists
    spark_df.write.csv(csv_path, mode = "append", header = False)  # Append new data EXCLUDING header columns
    print(f"Data APPENDED to {csv_path}")
else:
    spark_df.write.csv(csv_path, mode = "overwrite", header = False)  # At first-time write, INCLUDE header columns
    print(f"Data SAVED to {csv_path}")  # Printed ONLY ON FIRST RUN of this cell; next run onward, 'print' in above 'if' runs
# Out:
# Data APPENDED to /content/spark_linkedin_jobs

# %% [markdown]
# **Reading the content again:**

# %%
from pyspark.sql.types import StructType, StructField, StringType, IntegerType

# Define schema
col_schema = StructType([
    StructField(col_headings[0], StringType(), True),
    StructField(col_headings[1], StringType(), True),
    StructField(col_headings[2], StringType(), True),
    StructField(col_headings[3], StringType(), True)
])

# Reading the content of 'spark_linkedin_jobs.csv'
r = spark.read.csv('/content/spark_linkedin_jobs', schema = col_schema, multiLine = True)

# r.toDF(*col_headings)
r.dropDuplicates()  # Remove duplicate rows

r.show(n = r.count(), truncate=False)  # 'r.count()' returns the total no. of rows
# Out:
# +-------------------------------------------+--------------------------------------+-------------------------------+------------+
# |Job_Title                                  |Company                               |Location                       |Job_Recency |
# +-------------------------------------------+--------------------------------------+-------------------------------+------------+
# |Data Analyst, Finance & Strategy, MarComms |Netflix                               |Los Angeles, CA                |17 hours ago|
# |Data Analyst                               |KFC                                   |Plano, TX                      |8 hours ago |
# |Analyst, Insights & Analytics              |LoopMe                                |New York, NY                   |19 hours ago|
# |Data Analyst                               |CULT GAIA                             |Los Angeles Metropolitan Area  |1 week ago  |
# |Data Analyst                               |Zest AI                               |Burbank, CA                    |4 days ago  |
# |Data Analyst                               |Cloudflare                            |Austin, TX                     |2 weeks ago |
# |Data Analyst                               |Kforce Inc                            |New York, NY                   |3 days ago  |
# |Data Analyst, Pricing                      |Lyft                                  |Seattle, WA                    |1 week ago  |
# |Data Analyst                               |Upstart                               |United States                  |1 week ago  |
# |Data Analyst                               |Birlasoft                             |Charlotte, NC                  |1 week ago  |
# |Data Analyst                               |Cloudflare                            |Dallas, TX                     |1 week ago  |
# |Analyst, Analytics                         |Toyota North America                  |Plano, TX                      |1 week ago  |
# |Data Analyst                               |Memorial Sloan Kettering Cancer Center|New York, NY                   |2 weeks ago |
# |Sales Data Analyst                         |Morgan Stanley                        |Boston, MA                     |1 week ago  |
# |Data Analyst Intern 2025                   |Voloridge Investment Management, LLC  |Jupiter, FL                    |5 days ago  |
# |Data Analyst                               |Cloudflare                            |Houston, TX                    |2 weeks ago |
# |Data Analyst                               |Radiant Digital                       |Brooklyn, NY                   |2 weeks ago |
# |Data Analyst                               |Synapticure                           |Chicago, IL                    |1 week ago  |
# |Data Analyst I                             |Protingent                            |Charlotte, NC                  |4 weeks ago |
# |Data Analyst                               |Healthcasts Media                     |New York City Metropolitan Area|6 days ago  |
# |Data Analyst - Power BI, SQL, & Python     |Insight Global                        |Charlotte Metro                |6 days ago  |
# |Data Analyst                               |QSC                                   |United States                  |1 week ago  |
# |Junior Data Analyst (contingent)           |ARETUM                                |Washington, DC                 |1 week ago  |
# |Data Analyst                               |Cloudflare                            |San Antonio, TX                |3 days ago  |
# |Senior Data Analyst (NY Hybrid)            |Experian                              |New York, NY                   |1 week ago  |
# |Data Analyst  (251934)                     |Eastridge Workforce Solutions         |New York, NY                   |1 week ago  |
# |Business Data Analyst                      |Mirion                                |Atlanta, GA                    |6 days ago  |
# |Data Analyst                               |Korn Ferry                            |California, United States      |1 week ago  |
# |Data Analyst                               |Advize                                |United States                  |4 days ago  |
# |Data Analyst                               |Korn Ferry                            |Washington DC-Baltimore Area   |2 weeks ago |
# |Data Analyst, Finance & Strategy, MarComms |Netflix                               |Los Angeles, CA                |17 hours ago|
# |Data Analyst II                            |The Hershey Company                   |Hershey, PA                    |8 hours ago |
# |Data Analyst                               |KFC                                   |Plano, TX                      |19 hours ago|
# |Data Analyst                               |CULT GAIA                             |Los Angeles Metropolitan Area  |1 week ago  |
# |Data Analyst                               |Zest AI                               |Burbank, CA                    |2 weeks ago |
# |Data Analyst                               |Cloudflare                            |Austin, TX                     |4 days ago  |
# |Data Analyst                               |Kforce Inc                            |New York, NY                   |3 days ago  |
# |Data Analyst, Pricing                      |Lyft                                  |Seattle, WA                    |1 week ago  |
# |Data Analyst                               |Upstart                               |United States                  |1 week ago  |
# |Data Analyst                               |Birlasoft                             |Charlotte, NC                  |1 week ago  |
# |Data Analyst                               |Cloudflare                            |Dallas, TX                     |1 week ago  |
# |Analyst, Analytics                         |Toyota North America                  |Plano, TX                      |1 week ago  |
# |Data Analyst                               |Memorial Sloan Kettering Cancer Center|New York, NY                   |2 weeks ago |
# |Sales Data Analyst                         |Morgan Stanley                        |Boston, MA                     |1 week ago  |
# |Data Analyst                               |Cloudflare                            |Houston, TX                    |5 days ago  |
# |Data Analyst                               |Radiant Digital                       |Brooklyn, NY                   |2 weeks ago |
# |Data Analyst                               |CoralTree Hospitality                 |Englewood, CO                  |1 week ago  |
# |Data Analyst                               |Synapticure                           |Chicago, IL                    |4 days ago  |
# |Data Analyst I                             |Protingent                            |Charlotte, NC                  |4 weeks ago |
# |Data Analyst                               |PrudentRx                             |Tampa, FL                      |6 days ago  |
# |Data Analyst                               |Healthcasts Media                     |New York City Metropolitan Area|1 month ago |
# |Data Analyst - Power BI, SQL, & Python     |Insight Global                        |Charlotte Metro                |6 days ago  |
# |Data Analyst                               |QSC                                   |United States                  |1 week ago  |
# |Junior Data Analyst (contingent)           |ARETUM                                |Washington, DC                 |1 week ago  |
# |Data Analyst                               |Medterra                              |United States                  |1 week ago  |
# |Data Analyst                               |Dexian                                |Tampa, FL                      |4 days ago  |
# |Data Analyst                               |Korn Ferry                            |Florida, United States         |1 week ago  |
# |Data Analyst                               |Tata Consultancy Services             |Irving, TX                     |4 days ago  |
# |Data Analyst                               |YunoJuno                              |United States                  |1 week ago  |
# |Data Analyst                               |Bamboo Insurance                      |United States                  |1 week ago  |
# |Data Analyst                               |Elder Research                        |Arlington, VA                  |6 days ago  |
# |Data Analyst                               |Korn Ferry                            |Georgia, United States         |1 week ago  |
# |Data Analyst - Marketing                   |FanDuel                               |New York, NY                   |4 days ago  |
# |Analyst II, Data and Insights              |Herbalife                             |Torrance, CA                   |3 days ago  |
# |Data Analyst                               |Korn Ferry                            |Virginia, United States        |1 week ago  |
# |Junior Data Analyst                        |Sesheng                               |United States                  |4 days ago  |
# |Data Analyst                               |Akkodis                               |United States                  |2 days ago  |
# |Business Data Analyst                      |Volt                                  |Sparks, NV                     |2 weeks ago |
# |Data Analyst                               |Numero Data                           |Herndon, VA                    |2 weeks ago |
# |Data Analyst                               |MGT                                   |Tinley Park, IL                |1 week ago  |
# |Data Analyst                               |PRI Global                            |United States                  |4 days ago  |
# |Senior Data Analyst                        |CyberCoders                           |Normal, IL                     |2 weeks ago |
# |Data Analyst                               |The Cypress Group                     |New York City Metropolitan Area|1 week ago  |
# |Data Analyst                               |IT Labs                               |United States                  |1 week ago  |
# |Data Analyst                               |Planet Interactive                    |San Francisco, CA              |1 week ago  |
# |Data Analyst                               |Korn Ferry                            |Delaware, United States        |4 days ago  |
# |Data Analysts                              |AutoRoboto                            |Mountain View, CA              |1 week ago  |
# |Data Analyst                               |Flexton Inc.                          |Cincinnati Metropolitan Area   |3 days ago  |
# |Data Analyst                               |Korn Ferry                            |Arkansas, United States        |4 days ago  |
# |Data Analyst                               |Korn Ferry                            |Connecticut, United States     |4 days ago  |
# |Data Analyst                               |Korn Ferry                            |Idaho, United States           |4 days ago  |
# +-------------------------------------------+--------------------------------------+-------------------------------+------------+

# %%
r.count()  # In first-run, count was 60; changed value indicates new data has been added
# Out:
# 120

# %%
spark.stop() # Stop session to free resources

# %%
# !rm -rf /content/spark_linkedin_jobs/  # Erase folder as the demonstration task is completed

# %% [markdown]
# # **Fetching using pandas**

# %%
from bs4 import BeautifulSoup
import requests, pandas as pd

# job_url = 'https://www.linkedin.com/jobs/data-analyst-jobs-pune/?currentJobId=3783699912&originalSubdomain=in'
job_url = "https://www.linkedin.com/jobs/search?keywords=Data%20Analyst&location=&geoId=&trk=public_jobs_jobs-search-bar_search-submit&position=1&pageNum=0"
souped = requests.get(job_url)

job_html = BeautifulSoup(souped.content, "html.parser")

#Fetch job titles (job positions)
job_titles = job_html.find_all('h3', {'class' : 'base-search-card__title'})
job_list = []
for i in job_titles: job_list.append(i.getText().strip())

#Fetch name of the company offering each job
company_name = job_html.find_all('h4', {'class' : 'base-search-card__subtitle'})
job_company = []
for i in company_name: job_company.append(i.getText().strip())

#Fetch job location
location = job_html.find_all('span', {'class' : 'job-search-card__location'})
job_location = []
for i in location: job_location.append(i.getText().strip())

#Recency of job posting
recency1 = job_html.find_all('time', {'class' : 'job-search-card__listdate--new'})
recency2 = job_html.find_all('time', {'class' : 'job-search-card__listdate'})
job_recency = []
for i in recency1: job_recency.append(i.getText().strip())
for i in recency2: job_recency.append(i.getText().strip())

#creating dataframe to store fetched job details
data = {'Job_Title' : job_list, 'Company' : job_company, 'Location' : job_location, 'Job_Recency' : job_recency}
pd_df = pd.DataFrame(data)

# Following block sends fetched job details to a CSV file

try:
    existing_df = pd.read_csv('pd_linkedin_jobs.csv')  # Try to read an existing CSV file
    updated_df = pd.concat([existing_df, pd_df], ignore_index = True)   # Append the new data to the existing DataFrame
    updated_df.to_csv('pd_linkedin_jobs.csv', index = False)    # Save the updated DataFrame back to the CSV file
    print(f"Data appended to {'pd_linkedin_jobs.csv'}")
except FileNotFoundError:
    pd_df.to_csv('pd_linkedin_jobs.csv', index = False)   # If the CSV file does not exist, create a new one
    print(f"Data saved to a new CSV file: {'pd_linkedin_jobs.csv'}")  # prints when data is fetch first ever time
# Out:
# Data saved to a new CSV file: pd_linkedin_jobs.csv

# %%
# Reading the saved 'pd_linkedin_jobs.csv' file
read_data = pd.read_csv('pd_linkedin_jobs.csv')
pd.set_option('display.max_rows', None)
read_data  # o/p showing 180 records as each run fetches 60 records and the above cell was run twice so it's appended same data
# Out:
#                                       Job_Title  \
# 0                                  Data Analyst
# 1                                  Data Analyst
# 2    Data Analyst, Finance & Strategy, MarComms
# 3                               Data Analyst II
# 4                                  Data Analyst
# 5                                  Data Analyst
# 6                                  Data Analyst
# 7                         Data Analyst, Pricing
# 8                                  Data Analyst
# 9                                  Data Analyst
# 10                                 Data Analyst
# 11                                 Data Analyst
# 12                                 Data Analyst
# 13                                 Data Analyst
# 14                                 Data Analyst
# 15                                 Data Analyst
# 16                                 Data Analyst
# 17                                 Data Analyst
# 18                                 Data Analyst
# 19                                 Data Analyst
# 20                                 Data Analyst
# 21                          Junior Data Analyst
# 22                                 Data Analyst
# 23                           Analyst, Analytics
# 24                                 Data Analyst
# 25                                 Data Analyst
# 26                                 Data Analyst
# 27                                 Data Analyst
# 28                                 Data Analyst
# 29                           Sales Data Analyst
# 30                                 Data Analyst
# 31                                 Data Analyst
# 32                     Data Analyst - Marketing
# 33                                 Data Analyst
# 34                                 Data Analyst
# 35                                 Data Analyst
# 36                                 Data Analyst
# 37               Staff Data Analyst, Compliance
# 38  Data Analyst - (SQL / Looker - 100% Remote)
# 39                                 Data Analyst
# 40                          Master Data Analyst
# 41                   Data Analyst - 100% Remote
# 42                          Junior Data Analyst
# 43                                 Data Analyst
# 44                              JR Data Analyst
# 45                                 Data Analyst
# 46       Data Analyst - Power BI, SQL, & Python
# 47                                 Data Analyst
# 48                                 Data Analyst
# 49                                 Data Analyst
# 50                                 Data Analyst
# 5     1 week ago
# 6     1 week ago
# 7    2 weeks ago
# 8     1 week ago
# 9     3 days ago
# 10    4 days ago
# 11    1 week ago
# 12    4 days ago
# 13    1 week ago
# 14    1 week ago
# 15    4 days ago
# 16    4 days ago
# 17    4 days ago
# 18    4 days ago
# 19    4 days ago
# 20   2 weeks ago
# 21    1 week ago
# 22    4 days ago
# 23    4 days ago
# 24    2 days ago
# 25    3 days ago
# 26    5 days ago
# 27    1 week ago
# 28    4 days ago
# 29    4 days ago
# 30    4 days ago
# 31   1 month ago
# 32   2 weeks ago
# 33    6 days ago
# 34    4 days ago
# 35    3 days ago
# 36     1 day ago
# 37    4 days ago
# 38    1 week ago
# 39    4 days ago
# 40    1 week ago
# 41    1 week ago
# 42    1 week ago
# 43    6 days ago
# 44   4 weeks ago
# 45    5 days ago
# 46    6 days ago
# 47    1 week ago
# 48    3 days ago
# 49    3 days ago
# 50    6 days ago
# 51    1 week ago
# 52    3 days ago
# 53    1 week ago
# 54    1 week ago
# 55    1 week ago
# 56    6 days ago
# 57    3 days ago
# 58    3 days ago
# 59    1 week ago

# %% [markdown]
# **Now, let us run the code again. We find that the output shows:** ```Data appended to pd_linkedin_jobs.csv
# ``` **whereas in the previous run (FIRST run) above, output shows** ```Data saved to a new CSV file: pd_linkedin_jobs.csv```.

# %%
from bs4 import BeautifulSoup
import requests, pandas as pd

# job_url = 'https://www.linkedin.com/jobs/data-analyst-jobs-pune/?currentJobId=3783699912&originalSubdomain=in'
job_url = "https://www.linkedin.com/jobs/search?keywords=Data%20Analyst&location=&geoId=&trk=public_jobs_jobs-search-bar_search-submit&position=1&pageNum=0"
souped = requests.get(job_url)

job_html = BeautifulSoup(souped.content, "html.parser")

#Fetch job titles (job positions)
job_titles = job_html.find_all('h3', {'class' : 'base-search-card__title'})
job_list = []
for i in job_titles: job_list.append(i.getText().strip())

#Fetch name of the company offering each job
company_name = job_html.find_all('h4', {'class' : 'base-search-card__subtitle'})
job_company = []
for i in company_name: job_company.append(i.getText().strip())

#Fetch job location
location = job_html.find_all('span', {'class' : 'job-search-card__location'})
job_location = []
for i in location: job_location.append(i.getText().strip())

#Recency of job posting
recency1 = job_html.find_all('time', {'class' : 'job-search-card__listdate--new'})
recency2 = job_html.find_all('time', {'class' : 'job-search-card__listdate'})
job_recency = []
for i in recency1: job_recency.append(i.getText().strip())
for i in recency2: job_recency.append(i.getText().strip())

#creating dataframe to store fetched job details
data = {'Job_Title' : job_list, 'Company' : job_company, 'Location' : job_location, 'Job_Recency' : job_recency}
pd_df = pd.DataFrame(data)

# Following block sends fetched job details to a CSV file

try:
    existing_df = pd.read_csv('pd_linkedin_jobs.csv')  # Try to read an existing CSV file
    updated_df = pd.concat([existing_df, pd_df], ignore_index = True)   # Append the new data to the existing DataFrame
    updated_df.to_csv('pd_linkedin_jobs.csv', index = False)    # Save the updated DataFrame back to the CSV file
    print(f"Data appended to {'pd_linkedin_jobs.csv'}")
except FileNotFoundError:
    pd_df.to_csv('pd_linkedin_jobs.csv', index = False)   # If the CSV file does not exist, create a new one
    print(f"Data saved to a new CSV file: {'pd_linkedin_jobs.csv'}")  # prints when data is fetch first ever time
# Out:
# Data appended to pd_linkedin_jobs.csv

# %% [markdown]
# **Now, if we read the CSV data again, it will show 120 records as we have run the code twice so far and each run is getting 60 records from LinkedIn.**

# %%
# Reading the saved 'pd_linkedin_jobs.csv' file
read_data = pd.read_csv('pd_linkedin_jobs.csv')
pd.set_option('display.max_rows', None)
read_data
# Out:
#                                        Job_Title  \
# 0                                   Data Analyst
# 1                                   Data Analyst
# 2     Data Analyst, Finance & Strategy, MarComms
# 3                                Data Analyst II
# 4                                   Data Analyst
# 5                                   Data Analyst
# 6                                   Data Analyst
# 7                          Data Analyst, Pricing
# 8                                   Data Analyst
# 9                                   Data Analyst
# 10                                  Data Analyst
# 11                                  Data Analyst
# 12                                  Data Analyst
# 13                                  Data Analyst
# 14                                  Data Analyst
# 15                                  Data Analyst
# 16                                  Data Analyst
# 17                                  Data Analyst
# 18                                  Data Analyst
# 19                                  Data Analyst
# 20                                  Data Analyst
# 21                           Junior Data Analyst
# 22                                  Data Analyst
# 23                            Analyst, Analytics
# 24                                  Data Analyst
# 25                                  Data Analyst
# 26                                  Data Analyst
# 27                                  Data Analyst
# 28                                  Data Analyst
# 29                            Sales Data Analyst
# 30                                  Data Analyst
# 31                                  Data Analyst
# 32                      Data Analyst - Marketing
# 33                                  Data Analyst
# 34                                  Data Analyst
# 35                                  Data Analyst
# 36                                  Data Analyst
# 37                Staff Data Analyst, Compliance
# 38   Data Analyst - (SQL / Looker - 100% Remote)
# 39                                  Data Analyst
# 40                           Master Data Analyst
# 41                    Data Analyst - 100% Remote
# 42                           Junior Data Analyst
# 43                                  Data Analyst
# 44                               JR Data Analyst
# 45                                  Data Analyst
# 46        Data Analyst - Power BI, SQL, & Python
# 47                                  Data Analyst
# 48                                  Data Analyst
# 49                                  Data Analyst
# 50                                  Data Analyst
# 51              Junior Data Analyst (contingent)
# 52                                 Data Analysts
# 53                                  Data Analyst
# 54               Senior Data Analyst (NY Hybrid)
# 55                                  Data Analyst
# 56                        Data Analyst  (251934)
# 57                                  Data Analyst
# 58                                  Data Analyst
# 59                         Business Data Analyst
# 60    Data Analyst, Finance & Strategy, MarComms
# 61                               Data Analyst II
# 62                                  Data Analyst
# 63                                  Data Analyst
# 64                                  Data Analyst
# 65                         Data Analyst, Pricing
# 66                                  Data Analyst
# 67                                  Data Analyst
# 68                                  Data Analyst
# 69                                  Data Analyst
# 70                                  Data Analyst
# 71                            Analyst, Analytics
# 72                                  Data Analyst
# 73                            Sales Data Analyst
# 74                                  Data Analyst
# 75                                  Data Analyst
# 76                                  Data Analyst
# 77                                  Data Analyst
# 78                                Data Analyst I
# 79                                  Data Analyst
# 80                                  Data Analyst
# 81        Data Analyst - Power BI, SQL, & Python
# 82                                  Data Analyst
# 83              Junior Data Analyst (contingent)
# 84                                  Data Analyst
# 85               Senior Data Analyst (NY Hybrid)
# 86                        Data Analyst  (251934)
# 87                         Business Data Analyst
# 88                                  Data Analyst
# 89                                  Data Analyst
# 90                                  Data Analyst
# 91   Data Analyst - (SQL / Looker - 100% Remote)
# 92                                  Data Analyst
# 93                                  Data Analyst
# 94                                  Data Analyst
# 95                                  Data Analyst
# 96                                  Data Analyst
# 97                                  Data Analyst
# 98                                  Data Analyst
# 99                                  Data Analyst
# 100                                 Data Analyst
# 101                     Data Analyst - Marketing
# 102                Analyst II, Data and Insights
# 103                                 Data Analyst
# 104                          Junior Data Analyst
# 105                        Business Data Analyst
# 106                                 Data Analyst
# 107                                 Data Analyst
# 108                          Senior Data Analyst
# 109                                 Data Analyst
# 110                                 Data Analyst
# 111                                 Data Analyst
# 112                                Data Analysts
# 113                                 Data Analyst
# 114                                 Data Analyst
# 115                                 Data Analyst
# 116                                 Data Analyst
# 117                                 Data Analyst
# 118                  Data Analyst - Epidemiology
# 119                Sr. Data Analyst (E-commerce)
#
#                                     Company                         Location  \
# 0                                       KFC                        Plano, TX
# 1                                   Zest AI                      Burbank, CA
# 2                                   Netflix                  Los Angeles, CA
# 3                       The Hershey Company                      Hershey, PA
# 4                                   Upstart                    United States
# 5                                 CULT GAIA    Los Angeles Metropolitan Area
# 6                                Korn Ferry        California, United States
# 7                                      Lyft                      Seattle, WA
# 8                                Korn Ferry       Connecticut, United States
# 9                                Cloudflare                       Austin, TX
# 10                               Kforce Inc                     New York, NY
# 11                               Korn Ferry          Virginia, United States
# 12                               Korn Ferry           Georgia, United States
# 13                               Korn Ferry     Washington DC-Baltimore Area
# 14                    CoralTree Hospitality                    Englewood, CO
# 15                               Korn Ferry           Florida, United States
# 16   Memorial Sloan Kettering Cancer Center                     New York, NY
# 17                                Birlasoft                    Charlotte, NC
# 18                              Numero Data                      Herndon, VA
# 19                               Korn Ferry          Delaware, United States
# 20                                 Medterra                    United States
# 21                                  Sesheng                    United States
# 22                                 IDB Bank                     New York, NY
# 23                     Toyota North America                        Plano, TX
# 24                               Cloudflare                       Dallas, TX
# 25                               Korn Ferry          Arkansas, United States
# 26                                 Synergis                    United States
# 27                               Korn Ferry             Idaho, United States
# 28                                PrudentRx                        Tampa, FL
# 29                           Morgan Stanley                       Boston, MA
# 30                         Bamboo Insurance                    United States
# 31                               Korn Ferry           Indiana, United States
# 32                                  FanDuel                     New York, NY
# 33                                Fynora Ai  New York City Metropolitan Area
# 34                               Korn Ferry          Oklahoma, United States
# 35                               Cloudflare                      Houston, TX
# 36                               Korn Ferry           Alabama, United States
# 37                                  Upstart                    United States
# 38                                   Optomi        New Jersey, United States
# 39                          Radiant Digital                     Brooklyn, NY
# 40                       Paradies Lagardère        Atlanta Metropolitan Area
# 41                                    Lensa                 Jacksonville, FL
# 42                         Seneca Resources                      Atlanta, GA
# 43                              Synapticure                      Chicago, IL
# 44                              Accroid Inc                 Philadelphia, PA
# 45                        Healthcasts Media  New York City Metropolitan Area
# 46                           Insight Global                  Charlotte Metro
# 47                     TPI Global Solutions                    United States
# 48                                 Lemonade                     New York, NY
# 49                   White Oak Partners LLC                       Durham, NC
# 50                                      QSC                    United States
# 51                                   ARETUM                   Washington, DC
# 52                               AutoRoboto                Mountain View, CA
# 53                               Cloudflare                  San Antonio, TX
# 54                                 Experian                     New York, NY
# 55                       Planet Interactive                San Francisco, CA
# 56            Eastridge Workforce Solutions                     New York, NY
# 57                             Flexton Inc.     Cincinnati Metropolitan Area
# 58                           Insight Global        Atlanta Metropolitan Area
# 59                                   Mirion                      Atlanta, GA
# 60                                  Netflix                  Los Angeles, CA
# 61                      The Hershey Company                      Hershey, PA
# 62                                      KFC                        Plano, TX
# 63                                CULT GAIA    Los Angeles Metropolitan Area
# 64                                  Zest AI                      Burbank, CA
# 65                                     Lyft                      Seattle, WA
# 66                               Cloudflare                       Austin, TX
# 67                               Kforce Inc                     New York, NY
# 68                                  Upstart                    United States
# 69                                Birlasoft                    Charlotte, NC
# 70                               Cloudflare                       Dallas, TX
# 71                     Toyota North America                        Plano, TX
# 72   Memorial Sloan Kettering Cancer Center                     New York, NY
# 73                           Morgan Stanley                       Boston, MA
# 74                               Cloudflare                      Houston, TX
# 75                          Radiant Digital                     Brooklyn, NY
# 76                    CoralTree Hospitality                    Englewood, CO
# 77                              Synapticure                      Chicago, IL
# 78                               Protingent                    Charlotte, NC
# 79                                PrudentRx                        Tampa, FL
# 80                        Healthcasts Media  New York City Metropolitan Area
# 81                           Insight Global                  Charlotte Metro
# 82                                      QSC                    United States
# 83                                   ARETUM                   Washington, DC
# 84                               Cloudflare                  San Antonio, TX
# 85                                 Experian                     New York, NY
# 86            Eastridge Workforce Solutions                     New York, NY
# 87                                   Mirion                      Atlanta, GA
# 88                               Korn Ferry        California, United States
# 89                               Korn Ferry     Washington DC-Baltimore Area
# 90                              Counterpart                    United States
# 91                                   Optomi        New Jersey, United States
# 92                         Cloud and Things                    United States
# 93                                 Medterra                    United States
# 94                                   Dexian                        Tampa, FL
# 95                               Korn Ferry           Florida, United States
# 96                Tata Consultancy Services                       Irving, TX
# 97                                 YunoJuno                    United States
# 98                         Bamboo Insurance                    United States
# 99                           Elder Research                    Arlington, VA
# 100                              Korn Ferry           Georgia, United States
# 101                                 FanDuel                     New York, NY
# 102                               Herbalife                     Torrance, CA
# 103                              Korn Ferry          Virginia, United States
# 104                                 Sesheng                    United States
# 105                                    Volt                       Sparks, NV
# 106                             Numero Data                      Herndon, VA
# 107                                     MGT                  Tinley Park, IL
# 108                             CyberCoders                       Normal, IL
# 109                              PRI Global                    United States
# 110                       The Cypress Group  New York City Metropolitan Area
# 111                              Korn Ferry          Delaware, United States
# 112                              AutoRoboto                Mountain View, CA
# 113                      Planet Interactive                San Francisco, CA
# 114                              Korn Ferry       Connecticut, United States
# 115                            Flexton Inc.     Cincinnati Metropolitan Area
